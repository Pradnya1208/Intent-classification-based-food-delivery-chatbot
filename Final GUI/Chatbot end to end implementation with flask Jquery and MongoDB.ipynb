# %%
import json 
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# %%
# !pip install colorama
# Out:
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (0.4.4)

# %%
with open('intents.json') as file:
    data = json.load(file)
    
train_patterns = [] # patterns
train_intents = [] # tags
labels = [] #tags
responses = []


for intent in data['intents']:
    for pattern in intent['patterns']:
        train_patterns.append(pattern)
        train_intents.append(intent['tag'])
    responses.append(intent['responses'])
    
    if intent['tag'] not in labels:
        labels.append(intent['tag'])
        
num_classes = len(labels)

# %%
print("train_patterns :", train_patterns[100])
print("train_intents :", train_intents[100])
print("num_classes :", num_classes)
# Out:
# train_patterns : I am hungry
# train_intents : menu
# num_classes : 23

# %% [markdown]
# ### Then we use `LabelEncoder()` function provided by scikit-learn to convert the target labels into a model understandable form.

# %%
label_encoder = LabelEncoder()
label_encoder.fit(train_intents)
train_intents = label_encoder.transform(train_intents)

# %% [markdown]
# ## Vectorization
#
# - We vectorize our text data corpus by using the “Tokenizer” class and it allows us to limit our vocabulary size up to some defined number.
#
# - When we use this class for the text pre-processing task, by default all punctuations will be removed, turning the texts into space-separated sequences of words, and these sequences are then split into lists of tokens.
#
# - They will then be indexed or vectorized. We can also add “oov_token” which is a value for “out of token” to deal with out of vocabulary words(tokens) at inference time.
#
# - The “pad_sequences” method is used to make all the training text sequences into the same size.

# %%
vocab_size = 11250
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=None)
tokenizer.fit_on_texts(train_patterns)

word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(train_patterns)

padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %%
print("train_patterns :", train_patterns[99])
print("sequences: ", sequences[99])
# Out:
# train_patterns : Im damn hungry
# sequences:  [204, 205, 127]

# %% [markdown]
# ## 1) Here, we have to deal with multiple inputs or multiple outputs. Hence, we'll use `Keras` `Sequential()` model.
#
# read more : [Kears Sequential model details](https://keras.io/guides/sequential_model/)
#
# ## 2) Loss Function: `sparse_categorical_crossentropy` : We are using this crossentropy loss function when there are two or more label classes.
# read more about [sparse_categorical_crossentropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy)

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 20, 16)            180000
#
#  global_average_pooling1d_9   (None, 16)               0
#  (GlobalAveragePooling1D)
#
#  dense_27 (Dense)            (None, 16)                272
#
#  dense_28 (Dense)            (None, 16)                272
#
#  dense_29 (Dense)            (None, 23)                391
#
# =================================================================
# Total params: 180,935
# Trainable params: 180,935
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 500
history = model.fit(padded_sequences, np.array(train_intents), epochs=epochs)
# Out:
# Epoch 1/500
# 12/12 [==============================] - 1s 16ms/step - loss: 3.1309 - accuracy: 0.0761
# Epoch 2/500
# 12/12 [==============================] - 0s 5ms/step - loss: 3.1212 - accuracy: 0.1440
# Epoch 3/500
# 12/12 [==============================] - 0s 5ms/step - loss: 3.1105 - accuracy: 0.1440
# Epoch 4/500
# 12/12 [==============================] - 0s 6ms/step - loss: 3.0984 - accuracy: 0.1440
# Epoch 5/500
# 12/12 [==============================] - 0s 6ms/step - loss: 3.0832 - accuracy: 0.1440
# Epoch 6/500
# 12/12 [==============================] - 0s 5ms/step - loss: 3.0651 - accuracy: 0.1440
# Epoch 7/500
# 12/12 [==============================] - 0s 5ms/step - loss: 3.0452 - accuracy: 0.1440
# Epoch 8/500
# 12/12 [==============================] - 0s 5ms/step - loss: 3.0208 - accuracy: 0.1440
# Epoch 9/500
# 12/12 [==============================] - 0s 5ms/step - loss: 2.9953 - accuracy: 0.1440
# Epoch 10/500
# 12/12 [==============================] - 0s 6ms/step - loss: 2.9694 - accuracy: 0.1440
# Epoch 11/500
# 12/12 [==============================] - 0s 7ms/step - loss: 2.9447 - accuracy: 0.1440
# Epoch 12/500
# 12/12 [==============================] - 0s 5ms/step - loss: 2.9247 - accuracy: 0.1440
# Epoch 13/500
# 12/12 [==============================] - 0s 5ms/step - loss: 2.9060 - accuracy: 0.1440
# Epoch 14/500
# 12/12 [==============================] - 0s 6ms/step - loss: 2.8914 - accuracy: 0.1440
# Epoch 15/500
# 12/12 [==============================] - 0s 5ms/step - loss: 2.8784 - accuracy: 0.1440
# Epoch 16/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.8640 - accuracy: 0.1440
# Epoch 17/500
# 12/12 [==============================] - 0s 6ms/step - loss: 2.8525 - accuracy: 0.1440
# Epoch 18/500
# 12/12 [==============================] - 0s 18ms/step - loss: 2.8391 - accuracy: 0.1440
# Epoch 19/500
# 12/12 [==============================] - 0s 5ms/step - loss: 2.8261 - accuracy: 0.1440
# Epoch 20/500
# 12/12 [==============================] - 0s 6ms/step - loss: 2.8119 - accuracy: 0.1440
# Epoch 21/500
# 12/12 [==============================] - 0s 7ms/step - loss: 2.7966 - accuracy: 0.1440
# Epoch 22/500
# 12/12 [==============================] - 0s 8ms/step - loss: 2.7791 - accuracy: 0.1467
# Epoch 23/500
# 12/12 [==============================] - 0s 7ms/step - loss: 2.7602 - accuracy: 0.1467
# Epoch 24/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.7401 - accuracy: 0.1467
# Epoch 25/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.7170 - accuracy: 0.1495
# Epoch 26/500
# 12/12 [==============================] - 0s 6ms/step - loss: 2.6941 - accuracy: 0.1576
# Epoch 27/500
# 12/12 [==============================] - 0s 5ms/step - loss: 2.6687 - accuracy: 0.1630
# Epoch 28/500
# 12/12 [==============================] - 0s 5ms/step - loss: 2.6423 - accuracy: 0.1685
# Epoch 29/500
# 12/12 [==============================] - 0s 6ms/step - loss: 2.6149 - accuracy: 0.1712
# Epoch 30/500
# 12/12 [==============================] - 0s 13ms/step - loss: 2.5855 - accuracy: 0.1712
# Epoch 31/500
# 12/12 [==============================] - 0s 8ms/step - loss: 2.5588 - accuracy: 0.1739
# Epoch 32/500
# 12/12 [==============================] - 0s 6ms/step - loss: 2.5307 - accuracy: 0.1739
# Epoch 33/500
# 12/12 [==============================] - 0s 5ms/step - loss: 2.5029 - accuracy: 0.1766: 0s - loss: 2.5029 - accuracy: 0.17
# Epoch 34/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.4766 - accuracy: 0.1821
# Epoch 35/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.4514 - accuracy: 0.1793
# Epoch 36/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.4242 - accuracy: 0.1766
# Epoch 37/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3977 - accuracy: 0.1957
# Epoch 38/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3721 - accuracy: 0.1875
# Epoch 39/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3436 - accuracy: 0.2092
# Epoch 40/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.3196 - accuracy: 0.2038
# Epoch 41/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2929 - accuracy: 0.2337
# Epoch 42/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2649 - accuracy: 0.2092
# Epoch 43/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2357 - accuracy: 0.2337
# Epoch 44/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.2102 - accuracy: 0.2418
# Epoch 45/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1821 - accuracy: 0.2609
# Epoch 46/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1540 - accuracy: 0.2554
# Epoch 47/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.1252 - accuracy: 0.2772
# Epoch 48/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0976 - accuracy: 0.2853
# Epoch 49/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0688 - accuracy: 0.3098
# Epoch 50/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0402 - accuracy: 0.3043
# Epoch 51/500
# 12/12 [==============================] - 0s 4ms/step - loss: 2.0105 - accuracy: 0.3315
# Epoch 52/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9810 - accuracy: 0.3288
# Epoch 53/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9537 - accuracy: 0.3370
# Epoch 54/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9248 - accuracy: 0.3505
# Epoch 55/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8947 - accuracy: 0.3560
# Epoch 56/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8652 - accuracy: 0.3696
# Epoch 57/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.8360 - accuracy: 0.3777
# Epoch 58/500
# 12/12 [==============================] - 0s 5ms/step - loss: 1.8068 - accuracy: 0.3832
# Epoch 59/500
# 12/12 [==============================] - 0s 15ms/step - loss: 1.7765 - accuracy: 0.4457
# Epoch 60/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.7484 - accuracy: 0.4783
# Epoch 61/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.7201 - accuracy: 0.4783
# Epoch 62/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6945 - accuracy: 0.4837
# Epoch 63/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6618 - accuracy: 0.4918
# Epoch 64/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.6306 - accuracy: 0.4973
# Epoch 65/500
# 12/12 [==============================] - 0s 5ms/step - loss: 1.6057 - accuracy: 0.5054
# Epoch 66/500
# 12/12 [==============================] - 0s 5ms/step - loss: 1.5737 - accuracy: 0.5027
# Epoch 67/500
# 12/12 [==============================] - 0s 5ms/step - loss: 1.5416 - accuracy: 0.5679
# Epoch 68/500
# 12/12 [==============================] - 0s 6ms/step - loss: 1.5151 - accuracy: 0.5707
# Epoch 69/500
# 12/12 [==============================] - 0s 5ms/step - loss: 1.4852 - accuracy: 0.5870
# Epoch 70/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4600 - accuracy: 0.6087
# Epoch 71/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.4277 - accuracy: 0.6005
# Epoch 72/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.3967 - accuracy: 0.6250
# Epoch 73/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.3680 - accuracy: 0.6603
# Epoch 74/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.3408 - accuracy: 0.6359
# Epoch 75/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.3135 - accuracy: 0.6467
# Epoch 76/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2859 - accuracy: 0.6821
# Epoch 77/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.2560 - accuracy: 0.6793
# Epoch 78/500
# 12/12 [==============================] - 0s 15ms/step - loss: 1.2278 - accuracy: 0.6875
# Epoch 79/500
# 12/12 [==============================] - 0s 5ms/step - loss: 1.2020 - accuracy: 0.6875
# Epoch 80/500
# 12/12 [==============================] - 0s 5ms/step - loss: 1.1755 - accuracy: 0.6957
# Epoch 81/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.1479 - accuracy: 0.7120
# Epoch 82/500
# 12/12 [==============================] - 0s 5ms/step - loss: 1.1205 - accuracy: 0.7147
# Epoch 83/500
# 12/12 [==============================] - 0s 5ms/step - loss: 1.1002 - accuracy: 0.7092
# Epoch 84/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0672 - accuracy: 0.7255
# Epoch 85/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.0434 - accuracy: 0.7418
# Epoch 86/500
# 12/12 [==============================] - 0s 5ms/step - loss: 1.0201 - accuracy: 0.7446
# Epoch 87/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9968 - accuracy: 0.7527
# Epoch 88/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9752 - accuracy: 0.7500
# Epoch 89/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9545 - accuracy: 0.7554
# Epoch 90/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9327 - accuracy: 0.7717
# Epoch 91/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.9158 - accuracy: 0.7799
# Epoch 92/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.8943 - accuracy: 0.7717
# Epoch 93/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.8751 - accuracy: 0.7935
# Epoch 94/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.8579 - accuracy: 0.7935
# Epoch 95/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.8379 - accuracy: 0.7962
# Epoch 96/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.8203 - accuracy: 0.7962
# Epoch 97/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.8068 - accuracy: 0.8016
# Epoch 98/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7889 - accuracy: 0.8098
# Epoch 99/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7729 - accuracy: 0.8234
# Epoch 100/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7611 - accuracy: 0.8288
# Epoch 101/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7512 - accuracy: 0.8288
# Epoch 102/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7320 - accuracy: 0.8342
# Epoch 103/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7141 - accuracy: 0.8397
# Epoch 104/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.7026 - accuracy: 0.8424
# Epoch 105/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6870 - accuracy: 0.8451
# Epoch 106/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6737 - accuracy: 0.8451
# Epoch 107/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6601 - accuracy: 0.8478
# Epoch 108/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6482 - accuracy: 0.8505
# Epoch 109/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6377 - accuracy: 0.8533
# Epoch 110/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6241 - accuracy: 0.8587
# Epoch 111/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.6126 - accuracy: 0.8614
# Epoch 112/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.6017 - accuracy: 0.8614
# Epoch 113/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5929 - accuracy: 0.8587
# Epoch 114/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5835 - accuracy: 0.8587
# Epoch 115/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5724 - accuracy: 0.8641
# Epoch 116/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5644 - accuracy: 0.8641
# Epoch 117/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5514 - accuracy: 0.8723
# Epoch 118/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5417 - accuracy: 0.8668
# Epoch 119/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5309 - accuracy: 0.8696
# Epoch 120/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.5213 - accuracy: 0.8804
# Epoch 121/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5117 - accuracy: 0.8804
# Epoch 122/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.5021 - accuracy: 0.8777
# Epoch 123/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4947 - accuracy: 0.8723
# Epoch 124/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4849 - accuracy: 0.8750
# Epoch 125/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4764 - accuracy: 0.8859
# Epoch 126/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4671 - accuracy: 0.8995
# Epoch 127/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4605 - accuracy: 0.8967
# Epoch 128/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4519 - accuracy: 0.8995
# Epoch 129/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4432 - accuracy: 0.9049
# Epoch 130/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4356 - accuracy: 0.9076
# Epoch 131/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4298 - accuracy: 0.9076
# Epoch 132/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.4234 - accuracy: 0.9076
# Epoch 133/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4164 - accuracy: 0.9076
# Epoch 134/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4076 - accuracy: 0.9103
# Epoch 135/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.4001 - accuracy: 0.9212
# Epoch 136/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3944 - accuracy: 0.9158
# Epoch 137/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3904 - accuracy: 0.9076
# Epoch 138/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3855 - accuracy: 0.9076
# Epoch 139/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3757 - accuracy: 0.9158
# Epoch 140/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3700 - accuracy: 0.9239
# Epoch 141/500
# 12/12 [==============================] - 0s 16ms/step - loss: 0.3662 - accuracy: 0.9212
# Epoch 142/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3573 - accuracy: 0.9185
# Epoch 143/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3507 - accuracy: 0.9185
# Epoch 144/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.3452 - accuracy: 0.9185
# Epoch 145/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3396 - accuracy: 0.9185
# Epoch 146/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.3372 - accuracy: 0.9239
# Epoch 147/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3301 - accuracy: 0.9239
# Epoch 148/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3262 - accuracy: 0.9185
# Epoch 149/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3216 - accuracy: 0.9185
# Epoch 150/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3162 - accuracy: 0.9185
# Epoch 151/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3109 - accuracy: 0.9212
# Epoch 152/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.3037 - accuracy: 0.9266
# Epoch 153/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2996 - accuracy: 0.9212
# Epoch 154/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2921 - accuracy: 0.9293
# Epoch 155/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2896 - accuracy: 0.9266
# Epoch 156/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2845 - accuracy: 0.9293
# Epoch 157/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2800 - accuracy: 0.9293
# Epoch 158/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2752 - accuracy: 0.9348
# Epoch 159/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2698 - accuracy: 0.9321
# Epoch 160/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2654 - accuracy: 0.9321
# Epoch 161/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2602 - accuracy: 0.9402
# Epoch 162/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2561 - accuracy: 0.9429
# Epoch 163/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2542 - accuracy: 0.9429
# Epoch 164/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2483 - accuracy: 0.9402
# Epoch 165/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2425 - accuracy: 0.9511
# Epoch 166/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2384 - accuracy: 0.9457
# Epoch 167/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.2346 - accuracy: 0.9511
# Epoch 168/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2297 - accuracy: 0.9565
# Epoch 169/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2267 - accuracy: 0.9592
# Epoch 170/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2222 - accuracy: 0.9592
# Epoch 171/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2197 - accuracy: 0.9701
# Epoch 172/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2161 - accuracy: 0.9484
# Epoch 173/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2099 - accuracy: 0.9647
# Epoch 174/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2071 - accuracy: 0.9592
# Epoch 175/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.2029 - accuracy: 0.9620
# Epoch 176/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1983 - accuracy: 0.9592
# Epoch 177/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1947 - accuracy: 0.9674
# Epoch 178/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1913 - accuracy: 0.9674
# Epoch 179/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1864 - accuracy: 0.9674
# Epoch 180/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1847 - accuracy: 0.9701
# Epoch 181/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1808 - accuracy: 0.9701
# Epoch 182/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1788 - accuracy: 0.9674
# Epoch 183/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1753 - accuracy: 0.9701
# Epoch 184/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1722 - accuracy: 0.9837
# Epoch 185/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1678 - accuracy: 0.9810
# Epoch 186/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1649 - accuracy: 0.9728
# Epoch 187/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1615 - accuracy: 0.9783
# Epoch 188/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1574 - accuracy: 0.9755
# Epoch 189/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1552 - accuracy: 0.9755
# Epoch 190/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1531 - accuracy: 0.9728
# Epoch 191/500
# 12/12 [==============================] - 0s 14ms/step - loss: 0.1508 - accuracy: 0.9783
# Epoch 192/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1472 - accuracy: 0.9755
# Epoch 193/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1440 - accuracy: 0.9755
# Epoch 194/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1404 - accuracy: 0.9755
# Epoch 195/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1385 - accuracy: 0.9783
# Epoch 196/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1365 - accuracy: 0.9755
# Epoch 197/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1337 - accuracy: 0.9755
# Epoch 198/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1303 - accuracy: 0.9837
# Epoch 199/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1290 - accuracy: 0.9837
# Epoch 200/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1266 - accuracy: 0.9864
# Epoch 201/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1237 - accuracy: 0.9837
# Epoch 202/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1208 - accuracy: 0.9891
# Epoch 203/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1198 - accuracy: 0.9864
# Epoch 204/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1172 - accuracy: 0.9864
# Epoch 205/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1150 - accuracy: 0.9891
# Epoch 206/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1126 - accuracy: 0.9864
# Epoch 207/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1116 - accuracy: 0.9864
# Epoch 208/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1095 - accuracy: 0.9891
# Epoch 209/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1068 - accuracy: 0.9891
# Epoch 210/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1046 - accuracy: 0.9891
# Epoch 211/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1033 - accuracy: 0.9891
# Epoch 212/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.1006 - accuracy: 0.9891
# Epoch 213/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.1004 - accuracy: 0.9891
# Epoch 214/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0970 - accuracy: 0.9891
# Epoch 215/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0954 - accuracy: 0.9918
# Epoch 216/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0943 - accuracy: 0.9918
# Epoch 217/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0923 - accuracy: 0.9891
# Epoch 218/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0906 - accuracy: 0.9891
# Epoch 219/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0886 - accuracy: 0.9891
# Epoch 220/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0868 - accuracy: 0.9918
# Epoch 221/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0859 - accuracy: 0.9918
# Epoch 222/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0838 - accuracy: 0.9891
# Epoch 223/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0838 - accuracy: 0.9946
# Epoch 224/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0810 - accuracy: 0.9946
# Epoch 225/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0793 - accuracy: 0.9946
# Epoch 226/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0786 - accuracy: 0.9946
# Epoch 227/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0765 - accuracy: 0.9946
# Epoch 228/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0759 - accuracy: 0.9973
# Epoch 229/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0744 - accuracy: 0.9946
# Epoch 230/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0728 - accuracy: 0.9973
# Epoch 231/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0710 - accuracy: 0.9973
# Epoch 232/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0702 - accuracy: 0.9973
# Epoch 233/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0694 - accuracy: 0.9973
# Epoch 234/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0692 - accuracy: 0.9946
# Epoch 235/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0672 - accuracy: 0.9973
# Epoch 236/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0659 - accuracy: 0.9973
# Epoch 237/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0642 - accuracy: 0.9973
# Epoch 238/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0630 - accuracy: 0.9973
# Epoch 239/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0618 - accuracy: 0.9973
# Epoch 240/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0609 - accuracy: 0.9973
# Epoch 241/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0594 - accuracy: 1.0000
# Epoch 242/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0587 - accuracy: 1.0000
# Epoch 243/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0575 - accuracy: 0.9973
# Epoch 244/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0568 - accuracy: 0.9973
# Epoch 245/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0555 - accuracy: 1.0000
# Epoch 246/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0549 - accuracy: 1.0000
# Epoch 247/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0542 - accuracy: 1.0000
# Epoch 248/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0527 - accuracy: 1.0000
# Epoch 249/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0521 - accuracy: 1.0000
# Epoch 250/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0509 - accuracy: 1.0000
# Epoch 251/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0502 - accuracy: 1.0000
# Epoch 252/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0490 - accuracy: 1.0000
# Epoch 253/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0480 - accuracy: 1.0000
# Epoch 254/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0475 - accuracy: 1.0000
# Epoch 255/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 256/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0453 - accuracy: 1.0000
# Epoch 257/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0453 - accuracy: 1.0000
# Epoch 258/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0443 - accuracy: 1.0000
# Epoch 259/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0431 - accuracy: 1.0000
# Epoch 260/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0424 - accuracy: 1.0000
# Epoch 261/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0419 - accuracy: 1.0000
# Epoch 262/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0411 - accuracy: 1.0000
# Epoch 263/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0404 - accuracy: 1.0000
# Epoch 264/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0399 - accuracy: 1.0000
# Epoch 265/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 266/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0385 - accuracy: 1.0000
# Epoch 267/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0378 - accuracy: 1.0000
# Epoch 268/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0370 - accuracy: 1.0000
# Epoch 269/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 270/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0360 - accuracy: 1.0000
# Epoch 271/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0354 - accuracy: 1.0000
# Epoch 272/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 273/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 274/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0333 - accuracy: 1.0000
# Epoch 275/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0327 - accuracy: 1.0000
# Epoch 276/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 277/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0323 - accuracy: 1.0000
# Epoch 278/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0314 - accuracy: 1.0000
# Epoch 279/500
# 12/12 [==============================] - 0s 16ms/step - loss: 0.0309 - accuracy: 1.0000
# Epoch 280/500
# 12/12 [==============================] - 0s 7ms/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 281/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0297 - accuracy: 1.0000
# Epoch 282/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 283/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0286 - accuracy: 1.0000
# Epoch 284/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0281 - accuracy: 1.0000
# Epoch 285/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0280 - accuracy: 1.0000
# Epoch 286/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0277 - accuracy: 1.0000
# Epoch 287/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0267 - accuracy: 1.0000
# Epoch 288/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0261 - accuracy: 1.0000
# Epoch 289/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0258 - accuracy: 1.0000
# Epoch 290/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0254 - accuracy: 1.0000
# Epoch 291/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 292/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0245 - accuracy: 1.0000
# Epoch 293/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0242 - accuracy: 1.0000
# Epoch 294/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0239 - accuracy: 1.0000
# Epoch 295/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0233 - accuracy: 1.0000
# Epoch 296/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0231 - accuracy: 1.0000
# Epoch 297/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 298/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 299/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 300/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 301/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 302/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0210 - accuracy: 1.0000
# Epoch 303/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0207 - accuracy: 1.0000
# Epoch 304/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0206 - accuracy: 1.0000
# Epoch 305/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 306/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 307/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 308/500
# 12/12 [==============================] - 0s 9ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 309/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 310/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0185 - accuracy: 1.0000
# Epoch 311/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0182 - accuracy: 1.0000
# Epoch 312/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0181 - accuracy: 1.0000
# Epoch 313/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 314/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0174 - accuracy: 1.0000
# Epoch 315/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0172 - accuracy: 1.0000
# Epoch 316/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0169 - accuracy: 1.0000
# Epoch 317/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0167 - accuracy: 1.0000
# Epoch 318/500
# 12/12 [==============================] - 0s 13ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 319/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 320/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 321/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 322/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0156 - accuracy: 1.0000
# Epoch 323/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0152 - accuracy: 1.0000
# Epoch 324/500
# 12/12 [==============================] - 0s 6ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 325/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0148 - accuracy: 1.0000
# Epoch 326/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 327/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 1.0000
# Epoch 328/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0142 - accuracy: 1.0000
# Epoch 329/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 330/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0137 - accuracy: 1.0000
# Epoch 331/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 332/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 1.0000
# Epoch 333/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 334/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0130 - accuracy: 1.0000
# Epoch 335/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0128 - accuracy: 1.0000
# Epoch 336/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 337/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0125 - accuracy: 1.0000
# Epoch 338/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0122 - accuracy: 1.0000
# Epoch 339/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0121 - accuracy: 1.0000
# Epoch 340/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0119 - accuracy: 1.0000
# Epoch 341/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 1.0000
# Epoch 342/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 343/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0114 - accuracy: 1.0000
# Epoch 344/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 345/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 346/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 347/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 348/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 349/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 1.0000
# Epoch 350/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 351/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0102 - accuracy: 1.0000
# Epoch 352/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0100 - accuracy: 1.0000
# Epoch 353/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0099 - accuracy: 1.0000
# Epoch 354/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 355/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 1.0000
# Epoch 356/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 357/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 1.0000
# Epoch 358/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 1.0000
# Epoch 359/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 1.0000
# Epoch 360/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 1.0000
# Epoch 361/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 362/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 1.0000
# Epoch 363/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 1.0000
# Epoch 364/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 1.0000
# Epoch 365/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0084 - accuracy: 1.0000
# Epoch 366/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 1.0000
# Epoch 367/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 368/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 1.0000
# Epoch 369/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 1.0000
# Epoch 370/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 371/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 372/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 1.0000
# Epoch 373/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 1.0000
# Epoch 374/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 375/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 1.0000
# Epoch 376/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 1.0000
# Epoch 377/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 378/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 1.0000
# Epoch 379/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 380/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 1.0000
# Epoch 381/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 1.0000
# Epoch 382/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 383/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 384/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 1.0000
# Epoch 385/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 1.0000
# Epoch 386/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 387/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 1.0000
# Epoch 388/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 1.0000
# Epoch 389/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 390/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 391/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 1.0000
# Epoch 392/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 393/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 1.0000
# Epoch 394/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 395/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 1.0000
# Epoch 396/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 397/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 398/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 399/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 400/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 401/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 402/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0053 - accuracy: 1.0000
# Epoch 403/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 404/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0052 - accuracy: 1.0000
# Epoch 405/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 406/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 1.0000
# Epoch 407/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 408/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 409/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 410/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0049 - accuracy: 1.0000
# Epoch 411/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0048 - accuracy: 1.0000
# Epoch 412/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 413/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0047 - accuracy: 1.0000
# Epoch 414/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 415/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0046 - accuracy: 1.0000
# Epoch 416/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 417/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0045 - accuracy: 1.0000
# Epoch 418/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0044 - accuracy: 1.0000
# Epoch 419/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 420/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 421/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 422/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 423/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0042 - accuracy: 1.0000
# Epoch 424/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 425/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 1.0000
# Epoch 426/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 427/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0040 - accuracy: 1.0000
# Epoch 428/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 429/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 1.0000
# Epoch 430/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 431/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 432/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 433/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 434/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 435/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0036 - accuracy: 1.0000
# Epoch 436/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 437/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 438/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 439/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 440/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0035 - accuracy: 1.0000
# Epoch 441/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 442/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 443/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 444/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 445/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0033 - accuracy: 1.0000
# Epoch 446/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 447/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 448/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 449/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 450/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 451/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0031 - accuracy: 1.0000
# Epoch 452/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 453/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 454/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 1.0000
# Epoch 455/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 456/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 457/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 458/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 459/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 460/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 461/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 462/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 463/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 464/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 465/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 466/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 467/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 468/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 469/500
# 12/12 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 470/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 471/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 1.0000
# Epoch 472/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 473/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 474/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 475/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 476/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 1.0000
# Epoch 477/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 478/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 479/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 480/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 481/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 482/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0023 - accuracy: 1.0000
# Epoch 483/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 484/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 1.0000
# Epoch 485/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 486/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 487/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 488/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 489/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 490/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0021 - accuracy: 1.0000
# Epoch 491/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 492/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 493/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 494/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 495/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 1.0000
# Epoch 496/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 497/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 498/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 499/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 500/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 1.0000

# %%
history_dict = history.history

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")


loss_values = history_dict['loss']
#val_loss_values=history_dict['val_loss']
plt.plot(loss_values,'b',label='training loss')
#plt.plot(val_loss_values,'r',label='val training loss')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
accuracy_values = history_dict['accuracy']
#val_accuracy_values=history_dict['val_accuracy']
#plt.plot(val_accuracy_values,'-r',label='val_accuracy')
plt.plot(accuracy_values,'-b',label='accuracy')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
y_pred = model.predict(padded_sequences)
y_result=[]
for i in y_pred:
    max_value = max(i)
    #print(max_value)
    y_result.append(np.where(i == max_value)[0][0])





from sklearn.metrics import confusion_matrix
#CM matrix for training data
plt.figure(figsize=(12,12))

matrix_nn = confusion_matrix(y_result, np.array(train_intents))

sns.heatmap(matrix_nn, annot=True, cbar=None, cmap="Blues", fmt = 'g')
plt.title("Confusion Matrix"), plt.tight_layout()
plt.ylabel("True Class"), plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# ## Save the models
#
# We are saving 3 different things separately
# - Classification model
# - fitted Tokenizer object
# - fitted label encoder object

# %%
# saving model
model.save("chat_model")

import pickle

# saving tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    

# saving label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(label_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# INFO:tensorflow:Assets written to: chat_model\assets

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\admin\anaconda3\lib\site-packages (4.0.1)

# %%
import json
import random
import datetime
import pymongo
import uuid

# %%
seat_count = 50
import urllib.parse
# Make sure Settings->Network Access has correct settings



password=urllib.parse.quote_plus("<password>")
database = urllib.parse.quote_plus("<database>")

URI= "mongodb+srv://<hostname>:" + password + "@cluster0.jpcjh.mongodb.net/" + database + "?" + "retryWrites=true&w=majority"
#client = pymongo.MongoClient(URI)
client = pymongo.MongoClient(URI, connect=False)

db = client["<database>"]
menu_collection = db["menu"]
feedback_collection = db["feedback"]
order_collection=db["Orders"]
bookings_collection = db["bookings"]

# %%
query = {"mainmenu": "Y"}

veg_data = menu_collection.find(query)
x=[]
for i in veg_data:
    if (i.get("breakfast")=="N") == True:
        x.append(i.get("item"))
x
# Out:
# ['Soups',
#  'Starters',
#  'Main Course',
#  'Snacks',
#  'Snacks',
#  'Breakfast',
#  'accompaniments']

# %%
# Order
def record_order(message):
    print("Saving customers order")
    print(message)
    items_ = message.split("||")


    arr_dict={}
    for j,i in enumerate(items_[1:-1]):
 
        str1_ = i.split(",")
        dict_name='item {}'.format(j)
        arr_dict[dict_name]={}
    
        arr_dict[dict_name]['item'] = str1_[0].split(":")[1]
        arr_dict[dict_name]['price'] = str1_[1].split(":")[1]
        arr_dict[dict_name]['quantity'] = str1_[2].split(":")[1]
        #print(arr_dict[dict_name])
    

    
    arr_dict["Total Price"]={}
    arr_dict["order_details"]={}
         
    orderplaced_id = str(uuid.uuid4())
    arr_dict["Total Price"]["total bill"] = items_[0].split(":")[1]
    arr_dict["order_details"]["OrderID"] = orderplaced_id
    
    # Adding the ordering time:
    now_ = datetime.datetime.now()
    booking_time_ = now_.strftime("%Y-%m-%d %H:%M:%S")
    arr_dict["order_details"]["OrderTime"] = booking_time_
    arr_dict["order_details"]["placed"]="yes"
    arr_dict["order_details"]["canceled"]="no"
    
    
    
    # Make the array of nested dictionary
    item_dict=[]
    item_dict.append(arr_dict)
    
    nested_dictionary =item_dict
    order_collection.insert_many(nested_dictionary)
    return orderplaced_id
    # get the order id
    
    
    
# Cancel Order
def cancel_order(order_id):
    print(order_id)
    result={}
    status_=""
    query = {"order_details.OrderID": order_id}
    doc_ = order_collection.find(query)
    
    for x in doc_:
        result = x
        
    print(result)
    status_=arr_dict["order_details"]["OrderStatus"]
    print(status_)
   
        
    if result:
        if status_ == 'placed':
            newvalues = {"OrderStatus": "canceled" } 


            order_itemX=['Total Price','_id','order_details', 'OrderStatus']
            cancelStr = "Cancelling your order with : "
            for i in result:
                if i not in order_itemX:
                    cancelStr+= "("+result[i]['quantity'] + "-" + result[i]['item'] + ") "
            
   
            cancelStr+="💰 ₹" + result['Total Price']['total bill'] + " will be refunded to your account."
    
            result["order_details"].update(newvalues)
            print(result)
            return cancelStr
        
        else:
            return "🚫 This order has been canceled already."
    
    else:
        return "Please enter correct Order ID and 📌before entering order ID send the 'cancel Order' message again." 


# Book a table:
seat_count = 50
def book_table():
    global seat_count
    seat_count = seat_count - 1
    booking_id = str(uuid.uuid4())
    now = datetime.datetime.now()
    booking_time = now.strftime("%Y-%m-%d %H:%M:%S")
    booking_doc = {"booking_id": booking_id, "booking_time": booking_time}
    bookings_collection.insert_one(booking_doc)
    return booking_id


def get_specific_response(tag):
    for intent in data['intents']:
        if intent['tag'] == tag:
            responses = intent['responses']
    response = random.choice(responses)
    return response


"""def show_menu():
    all_items = menu_collection.distinct('item')
    response = ', '.join(all_items)
    return response"""

def record_feedback(message, type):
    print("Recording your feedback")
    feedback_doc = {"feedback_string": message, "type": type}
    feedback_collection.insert_one(feedback_doc)
    
def recipe_enquiry(inp):
    response=""
    for i in menu_collection.distinct('item'):
        if i.lower() in inp.lower():
            #print(i)
            #if inp.lower()== i.lower():
        
            query_about= {"item":i}
            about = menu_collection.find(query_about)
            for j in about:
                response = j.get("details")
        
            
    if response =="":
        response = "I don't know much about this recipe! But, you can contact our restaurant for more details."
    return response


def suggest():
    day = datetime.datetime.now()
    day = day.strftime("%A")
    if day == "Monday":
        response = "I would recommend: Paneer Roll and Chicken Biryani"
    elif day == "Tuesday":
        response = "I would recommend: Cheese Grilled Sandwich and Chicken tripple rice"

    elif day == "Wednesday":
        response = "I would recommend: Egg Roll and Latte "

    elif day == "Thursday":
        response = "I would recommend: Mixed Fruit Juice and Chicken cheese sandwich"

    elif day == "Friday":
        response = "I would recommend: White Sauce Pasta and Cheese cake"

    elif day == "Saturday":
        response = "I would recommend: Chicken Roll and cold coffee"

    elif day == "Sunday":
        response = "I would recommend: Schezwan Rice and Manchurian"
    return response

"""
def veg_menu():
    res=[]    
    query = {"veg": "Y"}
    b_query = {"Breads": "Y"}
    d_query = {"Desert": "Y"}
    i_query = {"icecreams_bev":"Y"}
    breads=[]
    deserts =[]
    ice_bev=[]


    b_doc = menu_collection.find(b_query)
    for x in b_doc:
        breads.append(x.get("item"))
    
    d_doc = menu_collection.find(d_query)
    for x in d_doc:
        deserts.append(x.get("item"))
    
    i_doc = menu_collection.find(i_query)
    for x in i_doc:
        ice_bev.append(x.get("item")) 
        
        
    veg_doc = menu_collection.find(query)
    for x in veg_doc:
        if x.get("item") not in exclude_items:
            res.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        
        
    return res"""

"""def nonveg_menu():
    query = {"nonveg": "Y"}
    vegan_doc = menu_collection.find(query)
    if vegan_doc.count() > 0:
        response = "Non-Vegetarian options are: "
        for x in vegan_doc:
            response = response + str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "; "
        response = response[:-2] # to remove the last ;
    else:
        response = "Sorry no vegetarian options are available"
    return response
"""

"""def nonveg_menu():
    re=[]
    query = {"nonveg": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        re.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return re




def breakfast_menu():
    br=[]
    query = {"breakfast": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        br.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        
    return br

def bevrages_menu():
    bev=[]
    query = {"icecreams_bev": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        bev.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        
    return bev

def dessert_menu():
    de=[]
    query = {"Desert": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        de.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
 
    return de

def snacks_menu():
    sn=[]
    query = {"snacks": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        sn.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
       
    return sn


def main_menu():
    menu=[]
    query = {"mainmenu": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        menu.append(str(x.get("item")) +"\n")
   
    return menu"""

def offers():
    
    response = "Sorry there are no offers available now."
    return response

# %%
def generate_response(tag, user_input):
    global seat_count
    #tag = get_intent(message)
    response = ""
    if tag != "":
        if tag == "book_table":

            if seat_count > 0:
                booking_id = book_table()
                response = "Your table has been booked successfully :" + str(
                    booking_id)
            else:
                response = "Sorry we are sold out now!"


        elif tag == "available_tables":
            response = "Right now, there are " + str(seat_count) + " table(s) available."

        elif tag == "veg_enquiry":
            response ="Hey, You can discover our amazing vegetarian options in the Menu section on your left."

        elif tag == "nonveg_enquiry":
            response = "Hey, You can discover Non-vegetarian food options in the Menu section on your left."
            
        elif tag == "vegan_enquiry":
            response = "Sorry, We don't serve Vegan Food"

        elif tag == "offers":
            response =offers()

        elif tag == "suggest":
            
            response =suggest()
            response+="\n"+"Or else you can check our populars in the Menu section!!"

        elif tag == "recipe_enquiry":
            response =recipe_enquiry(user_input)

        elif tag == "menu":
            response="Checkout our lip-smacking food options on your left. Just add whichever food item you like." + "\n" + "worried about recipes and ingredients? ask me!!. I've got you covered 😎"
            
        elif tag == "Icecreams_bevrages":
            response = "Checkout Desserts option for the refreshing bevrages!! 🍨"
            
        elif tag == "Quick_Bites":
          
            response = "Hey, You can explore breakfast, Snacks and Desserts options on your left for some quick refreshments!!"
            
        elif tag == "positive_feedback":
            record_feedback(user_input, "positive")
            response = "Huzzah!!😍 Thank you so much for your valuable feedback. We look forward to serving you again!"

        elif "negative_feedback" == tag:
            record_feedback(user_input, "negative")
            response = "Thank you so much for your valuable feedback. We deeply regret the inconvenience. We have " \
                       "forwarded your concerns to the authority and hope to satisfy you better the next time! 🙏"
        # for other intents with pre-defined responses that can be pulled from dataset
        else:
            response = get_specific_response(tag)
    else:
        response = "Sorry! I didn't get it, please try to be more precise."
    return response

# %% [markdown]
# ### Load the model

# %%
def response_gen(message):
    model = keras.models.load_model('chat_model')

    # load tokenizer object
    with open('tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # load label encoder object
    with open('label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # parameters
    max_len = 20
    
    result = model.predict(keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([message]),truncating='post', maxlen=max_len))
    
    ## Find the intent
    tag = lbl_encoder.inverse_transform([np.argmax(result)])
    print(tag)

    for i in data['intents']:
        if i['tag'] == tag:
            output = generate_response(tag, message)
            
    return output

# %%
from flask import Flask, render_template, request, jsonify
import json 
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder
import os

ORDER_ID=False

TEMPLATE_DIR = os.path.abspath('./templates')
STATIC_DIR = os.path.abspath('./static')

app = Flask(__name__) # to make the app run without any

@app.route('/')
def index():
    return render_template('index.html')


@app.route('/get')
def get_bot_response():
    
    message = request.args.get('msg')
    #print(message)
    response = ""
    if message:
        if message.startswith("TotalPrice:"):
            print(message)
            o_id = record_order(message)
            id_res = "Your Order ID is : " + o_id + " Kindly remember this ID for the future reference."
            return id_res
        #Order Cancel
        elif message.endswith("-ORDERID"):
            # if intent is Cancel
            print(message)
            
            cancelOrderStr = cancel_order(message.split("-ORDERID")[0])
            
            return cancelOrderStr
            
            
            
        else:
            response = response_gen(message)
            #print(response)
            
                
        
        return str(response)
    
    else:
        return "Missing Data!"
    


if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [16/Feb/2022 21:16:38] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [16/Feb/2022 21:16:38] "GET /style.css HTTP/1.1" 404 -
# 127.0.0.1 - - [16/Feb/2022 21:16:38] "GET /script.js HTTP/1.1" 404 -
# 127.0.0.1 - - [16/Feb/2022 21:16:38] "GET /script.js HTTP/1.1" 404 -
# 127.0.0.1 - - [16/Feb/2022 21:16:44] "GET /get?msg=TotalPrice%3A10%7C%7CProductName%3Aproduct+1%2CproductPrice%3A10%2CproductQuantity%3A1%7C%7C HTTP/1.1" 200 -
# TotalPrice:10||ProductName:product 1,productPrice:10,productQuantity:1||
# Saving customers order
# TotalPrice:10||ProductName:product 1,productPrice:10,productQuantity:1||
