# %%
import json 
import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, GlobalAveragePooling1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder

# %%
# !pip install colorama
# Out:
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (0.4.4)

# %%
with open('intents.json') as file:
    data = json.load(file)
    
train_patterns = [] # patterns
train_intents = [] # tags
labels = [] #tags
responses = []


for intent in data['intents']:
    for pattern in intent['patterns']:
        train_patterns.append(pattern)
        train_intents.append(intent['tag'])
    responses.append(intent['responses'])
    
    if intent['tag'] not in labels:
        labels.append(intent['tag'])
        
num_classes = len(labels)

# %%
print("train_patterns :", train_patterns[100])
print("train_intents :", train_intents[100])
print("num_classes :", num_classes)
# Out:
# train_patterns : What to eat
# train_intents : menu
# num_classes : 22

# %% [markdown]
# ### Then we use `LabelEncoder()` function provided by scikit-learn to convert the target labels into a model understandable form.

# %%
label_encoder = LabelEncoder()
label_encoder.fit(train_intents)
train_intents = label_encoder.transform(train_intents)

# %% [markdown]
# ## Vectorization
#
# - We vectorize our text data corpus by using the “Tokenizer” class and it allows us to limit our vocabulary size up to some defined number.
#
# - When we use this class for the text pre-processing task, by default all punctuations will be removed, turning the texts into space-separated sequences of words, and these sequences are then split into lists of tokens.
#
# - They will then be indexed or vectorized. We can also add “oov_token” which is a value for “out of token” to deal with out of vocabulary words(tokens) at inference time.
#
# - The “pad_sequences” method is used to make all the training text sequences into the same size.

# %%
vocab_size = 11250
embedding_dim = 16
max_len = 20
oov_token = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=None)
tokenizer.fit_on_texts(train_patterns)

word_index = tokenizer.word_index
sequences = tokenizer.texts_to_sequences(train_patterns)

padded_sequences = pad_sequences(sequences, truncating='post', maxlen=max_len)

# %%
print("train_patterns :", train_patterns[99])
print("sequences: ", sequences[99])
# Out:
# train_patterns : I am hungry
# sequences:  [2, 31, 127]

# %% [markdown]
# ## 1) Here, we have to deal with multiple inputs or multiple outputs. Hence, we'll use `Keras` `Sequential()` model.
#
# read more : [Kears Sequential model details](https://keras.io/guides/sequential_model/)
#
# ## 2) Loss Function: `sparse_categorical_crossentropy` : We are using this crossentropy loss function when there are two or more label classes.
# read more about [sparse_categorical_crossentropy](https://www.tensorflow.org/api_docs/python/tf/keras/losses/SparseCategoricalCrossentropy)

# %%
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=max_len))
model.add(GlobalAveragePooling1D())
model.add(Dense(16, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss='sparse_categorical_crossentropy', 
              optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 16)            180000
#
#  global_average_pooling1d (G  (None, 16)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 16)                272
#
#  dense_1 (Dense)             (None, 16)                272
#
#  dense_2 (Dense)             (None, 22)                374
#
# =================================================================
# Total params: 180,918
# Trainable params: 180,918
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs = 500
history = model.fit(padded_sequences, np.array(train_intents), epochs=epochs)
# Out:
# Epoch 1/500
# 12/12 [==============================] - 1s 3ms/step - loss: 3.0815 - accuracy: 0.1114
# Epoch 2/500
# 12/12 [==============================] - 0s 2ms/step - loss: 3.0658 - accuracy: 0.1576
# Epoch 3/500
# 12/12 [==============================] - 0s 2ms/step - loss: 3.0466 - accuracy: 0.1522
# Epoch 4/500
# 12/12 [==============================] - 0s 3ms/step - loss: 3.0237 - accuracy: 0.1821
# Epoch 5/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.9999 - accuracy: 0.1766
# Epoch 6/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.9722 - accuracy: 0.1495
# Epoch 7/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.9451 - accuracy: 0.1304
# Epoch 8/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.9232 - accuracy: 0.1332
# Epoch 9/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.9030 - accuracy: 0.1386
# Epoch 10/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8907 - accuracy: 0.1386
# Epoch 11/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8800 - accuracy: 0.1630
# Epoch 12/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8698 - accuracy: 0.1848
# Epoch 13/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8610 - accuracy: 0.2120
# Epoch 14/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8507 - accuracy: 0.1440
# Epoch 15/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8406 - accuracy: 0.1440
# Epoch 16/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.8305 - accuracy: 0.1386
# Epoch 17/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8183 - accuracy: 0.1386
# Epoch 18/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.8057 - accuracy: 0.1386
# Epoch 19/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.7933 - accuracy: 0.1386
# Epoch 20/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.7755 - accuracy: 0.1386
# Epoch 21/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.7580 - accuracy: 0.1386
# Epoch 22/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.7403 - accuracy: 0.1386
# Epoch 23/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.7193 - accuracy: 0.1386
# Epoch 24/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.6961 - accuracy: 0.1386
# Epoch 25/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.6743 - accuracy: 0.1413
# Epoch 26/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.6493 - accuracy: 0.1549
# Epoch 27/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.6238 - accuracy: 0.1576
# Epoch 28/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.5983 - accuracy: 0.1603
# Epoch 29/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.5723 - accuracy: 0.1712
# Epoch 30/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.5437 - accuracy: 0.1739
# Epoch 31/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.5169 - accuracy: 0.1739
# Epoch 32/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.4893 - accuracy: 0.1766
# Epoch 33/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.4604 - accuracy: 0.1766
# Epoch 34/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.4367 - accuracy: 0.1766
# Epoch 35/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.4079 - accuracy: 0.1766
# Epoch 36/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.3810 - accuracy: 0.1875
# Epoch 37/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.3571 - accuracy: 0.1875
# Epoch 38/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.3319 - accuracy: 0.1902
# Epoch 39/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.3085 - accuracy: 0.1984
# Epoch 40/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2879 - accuracy: 0.1957
# Epoch 41/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2610 - accuracy: 0.2065
# Epoch 42/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.2374 - accuracy: 0.2011
# Epoch 43/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.2124 - accuracy: 0.2120
# Epoch 44/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.1879 - accuracy: 0.2391
# Epoch 45/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.1610 - accuracy: 0.2473
# Epoch 46/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.1347 - accuracy: 0.2609
# Epoch 47/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.1090 - accuracy: 0.2880
# Epoch 48/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.0822 - accuracy: 0.2799
# Epoch 49/500
# 12/12 [==============================] - 0s 2ms/step - loss: 2.0551 - accuracy: 0.2908
# Epoch 50/500
# 12/12 [==============================] - 0s 3ms/step - loss: 2.0235 - accuracy: 0.2826
# Epoch 51/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.9937 - accuracy: 0.3370
# Epoch 52/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.9587 - accuracy: 0.3668
# Epoch 53/500
# 12/12 [==============================] - 0s 4ms/step - loss: 1.9289 - accuracy: 0.3668
# Epoch 54/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8927 - accuracy: 0.3750
# Epoch 55/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.8575 - accuracy: 0.3967
# Epoch 56/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.8247 - accuracy: 0.4130
# Epoch 57/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.7918 - accuracy: 0.4049
# Epoch 58/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.7567 - accuracy: 0.4293
# Epoch 59/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.7257 - accuracy: 0.4783
# Epoch 60/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6868 - accuracy: 0.5000
# Epoch 61/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6594 - accuracy: 0.4891
# Epoch 62/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.6245 - accuracy: 0.5109
# Epoch 63/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5871 - accuracy: 0.5408
# Epoch 64/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5573 - accuracy: 0.5380
# Epoch 65/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.5258 - accuracy: 0.5897
# Epoch 66/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4920 - accuracy: 0.5870
# Epoch 67/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4604 - accuracy: 0.6114
# Epoch 68/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.4301 - accuracy: 0.6168
# Epoch 69/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3989 - accuracy: 0.6304
# Epoch 70/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3694 - accuracy: 0.6304
# Epoch 71/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3410 - accuracy: 0.6495
# Epoch 72/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.3164 - accuracy: 0.6495
# Epoch 73/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2918 - accuracy: 0.6386
# Epoch 74/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2657 - accuracy: 0.6685
# Epoch 75/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.2369 - accuracy: 0.6603
# Epoch 76/500
# 12/12 [==============================] - 0s 3ms/step - loss: 1.2128 - accuracy: 0.6658
# Epoch 77/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1895 - accuracy: 0.6793
# Epoch 78/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1653 - accuracy: 0.6766
# Epoch 79/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1419 - accuracy: 0.6821
# Epoch 80/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1210 - accuracy: 0.6712
# Epoch 81/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.1009 - accuracy: 0.6929
# Epoch 82/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0771 - accuracy: 0.6957
# Epoch 83/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0610 - accuracy: 0.6821
# Epoch 84/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0449 - accuracy: 0.7038
# Epoch 85/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0225 - accuracy: 0.7065
# Epoch 86/500
# 12/12 [==============================] - 0s 2ms/step - loss: 1.0025 - accuracy: 0.7337
# Epoch 87/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9846 - accuracy: 0.7228
# Epoch 88/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9700 - accuracy: 0.7391
# Epoch 89/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.9493 - accuracy: 0.7446
# Epoch 90/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9400 - accuracy: 0.7283
# Epoch 91/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9217 - accuracy: 0.7283
# Epoch 92/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.9025 - accuracy: 0.7364
# Epoch 93/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8872 - accuracy: 0.7554
# Epoch 94/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8733 - accuracy: 0.7554
# Epoch 95/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8576 - accuracy: 0.7582
# Epoch 96/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8446 - accuracy: 0.7582
# Epoch 97/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.8313 - accuracy: 0.7636
# Epoch 98/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8179 - accuracy: 0.7609
# Epoch 99/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.8056 - accuracy: 0.7663
# Epoch 100/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7901 - accuracy: 0.7554
# Epoch 101/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.7756 - accuracy: 0.7826
# Epoch 102/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7627 - accuracy: 0.7609
# Epoch 103/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7508 - accuracy: 0.7663
# Epoch 104/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7345 - accuracy: 0.7717
# Epoch 105/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7225 - accuracy: 0.8043
# Epoch 106/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.7080 - accuracy: 0.7853
# Epoch 107/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6986 - accuracy: 0.8043
# Epoch 108/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6842 - accuracy: 0.8261
# Epoch 109/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6726 - accuracy: 0.8397
# Epoch 110/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6605 - accuracy: 0.8397
# Epoch 111/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.6464 - accuracy: 0.8370
# Epoch 112/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6328 - accuracy: 0.8424
# Epoch 113/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6226 - accuracy: 0.8533
# Epoch 114/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.6138 - accuracy: 0.8533
# Epoch 115/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5996 - accuracy: 0.8614
# Epoch 116/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5897 - accuracy: 0.8614
# Epoch 117/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5802 - accuracy: 0.8641
# Epoch 118/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5660 - accuracy: 0.8696
# Epoch 119/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5559 - accuracy: 0.8668
# Epoch 120/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5491 - accuracy: 0.8750
# Epoch 121/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5372 - accuracy: 0.8668
# Epoch 122/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.5249 - accuracy: 0.8832
# Epoch 123/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5135 - accuracy: 0.8859
# Epoch 124/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.5050 - accuracy: 0.8913
# Epoch 125/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4946 - accuracy: 0.8913
# Epoch 126/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4880 - accuracy: 0.8859
# Epoch 127/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4775 - accuracy: 0.8832
# Epoch 128/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4658 - accuracy: 0.9049
# Epoch 129/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4553 - accuracy: 0.9103
# Epoch 130/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4455 - accuracy: 0.8967
# Epoch 131/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4330 - accuracy: 0.9185
# Epoch 132/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4267 - accuracy: 0.9049
# Epoch 133/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4177 - accuracy: 0.9185
# Epoch 134/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.4071 - accuracy: 0.9239
# Epoch 135/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.4012 - accuracy: 0.9185
# Epoch 136/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3888 - accuracy: 0.9348
# Epoch 137/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3808 - accuracy: 0.9429
# Epoch 138/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3718 - accuracy: 0.9321
# Epoch 139/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3640 - accuracy: 0.9429
# Epoch 140/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.3575 - accuracy: 0.9457
# Epoch 141/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3448 - accuracy: 0.9484
# Epoch 142/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3369 - accuracy: 0.9457
# Epoch 143/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3294 - accuracy: 0.9538
# Epoch 144/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3248 - accuracy: 0.9484
# Epoch 145/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3177 - accuracy: 0.9620
# Epoch 146/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.3080 - accuracy: 0.9674
# Epoch 147/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2993 - accuracy: 0.9728
# Epoch 148/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2912 - accuracy: 0.9701
# Epoch 149/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2824 - accuracy: 0.9755
# Epoch 150/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2768 - accuracy: 0.9701
# Epoch 151/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2709 - accuracy: 0.9837
# Epoch 152/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2626 - accuracy: 0.9837
# Epoch 153/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2597 - accuracy: 0.9783
# Epoch 154/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2500 - accuracy: 0.9864
# Epoch 155/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2443 - accuracy: 0.9837
# Epoch 156/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2400 - accuracy: 0.9864
# Epoch 157/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.2345 - accuracy: 0.9864
# Epoch 158/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2292 - accuracy: 0.9864
# Epoch 159/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2231 - accuracy: 0.9837
# Epoch 160/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2182 - accuracy: 0.9837
# Epoch 161/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2129 - accuracy: 0.9864
# Epoch 162/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2082 - accuracy: 0.9864
# Epoch 163/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.2028 - accuracy: 0.9864
# Epoch 164/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1994 - accuracy: 0.9864
# Epoch 165/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1938 - accuracy: 0.9864
# Epoch 166/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1888 - accuracy: 0.9864
# Epoch 167/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1845 - accuracy: 0.9864
# Epoch 168/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1807 - accuracy: 0.9864
# Epoch 169/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1773 - accuracy: 0.9864
# Epoch 170/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1740 - accuracy: 0.9864
# Epoch 171/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1716 - accuracy: 0.9837
# Epoch 172/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1645 - accuracy: 0.9864
# Epoch 173/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1635 - accuracy: 0.9864
# Epoch 174/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1592 - accuracy: 0.9864
# Epoch 175/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1553 - accuracy: 0.9864
# Epoch 176/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1552 - accuracy: 0.9864
# Epoch 177/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1484 - accuracy: 0.9864
# Epoch 178/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1452 - accuracy: 0.9864
# Epoch 179/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1418 - accuracy: 0.9864
# Epoch 180/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1396 - accuracy: 0.9864
# Epoch 181/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1363 - accuracy: 0.9864
# Epoch 182/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1342 - accuracy: 0.9864
# Epoch 183/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1327 - accuracy: 0.9864
# Epoch 184/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1291 - accuracy: 0.9864
# Epoch 185/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1257 - accuracy: 0.9864
# Epoch 186/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1237 - accuracy: 0.9864
# Epoch 187/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1234 - accuracy: 0.9864
# Epoch 188/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1196 - accuracy: 0.9864
# Epoch 189/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1187 - accuracy: 0.9891
# Epoch 190/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.1154 - accuracy: 0.9864
# Epoch 191/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1137 - accuracy: 0.9864
# Epoch 192/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1106 - accuracy: 0.9891
# Epoch 193/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1087 - accuracy: 0.9891
# Epoch 194/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1069 - accuracy: 0.9864
# Epoch 195/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1048 - accuracy: 0.9891
# Epoch 196/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1023 - accuracy: 0.9864
# Epoch 197/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.1009 - accuracy: 0.9864
# Epoch 198/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0995 - accuracy: 0.9891
# Epoch 199/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0963 - accuracy: 0.9918
# Epoch 200/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0947 - accuracy: 0.9918
# Epoch 201/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0940 - accuracy: 0.9891
# Epoch 202/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0915 - accuracy: 0.9918
# Epoch 203/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0901 - accuracy: 0.9918
# Epoch 204/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0890 - accuracy: 0.9918
# Epoch 205/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0867 - accuracy: 0.9918
# Epoch 206/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0859 - accuracy: 0.9918
# Epoch 207/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0834 - accuracy: 0.9918
# Epoch 208/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0838 - accuracy: 0.9918
# Epoch 209/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0811 - accuracy: 0.9918
# Epoch 210/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0800 - accuracy: 0.9918
# Epoch 211/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0787 - accuracy: 0.9918
# Epoch 212/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0766 - accuracy: 0.9918
# Epoch 213/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0769 - accuracy: 0.9918
# Epoch 214/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0760 - accuracy: 0.9918
# Epoch 215/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0744 - accuracy: 0.9946
# Epoch 216/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0716 - accuracy: 0.9918
# Epoch 217/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0710 - accuracy: 0.9918
# Epoch 218/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0697 - accuracy: 0.9918
# Epoch 219/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0681 - accuracy: 0.9918
# Epoch 220/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0678 - accuracy: 0.9918
# Epoch 221/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 0.9918
# Epoch 222/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0650 - accuracy: 0.9918
# Epoch 223/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0648 - accuracy: 0.9918
# Epoch 224/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0634 - accuracy: 0.9918
# Epoch 225/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0623 - accuracy: 0.9946
# Epoch 226/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0610 - accuracy: 0.9918
# Epoch 227/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0607 - accuracy: 0.9891
# Epoch 228/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0598 - accuracy: 0.9918
# Epoch 229/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0591 - accuracy: 0.9946
# Epoch 230/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0571 - accuracy: 0.9946
# Epoch 231/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0564 - accuracy: 0.9946
# Epoch 232/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0557 - accuracy: 0.9946
# Epoch 233/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0550 - accuracy: 0.9946
# Epoch 234/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0542 - accuracy: 0.9946
# Epoch 235/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0534 - accuracy: 0.9918
# Epoch 236/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0519 - accuracy: 0.9946
# Epoch 237/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0511 - accuracy: 0.9946
# Epoch 238/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0508 - accuracy: 0.9946
# Epoch 239/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0501 - accuracy: 0.9946
# Epoch 240/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0490 - accuracy: 0.9946
# Epoch 241/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0485 - accuracy: 0.9946
# Epoch 242/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0479 - accuracy: 0.9946
# Epoch 243/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0469 - accuracy: 0.9946
# Epoch 244/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0460 - accuracy: 0.9946
# Epoch 245/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0456 - accuracy: 0.9946
# Epoch 246/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0450 - accuracy: 0.9946
# Epoch 247/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0448 - accuracy: 0.9946
# Epoch 248/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0444 - accuracy: 0.9918
# Epoch 249/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0455 - accuracy: 0.9946
# Epoch 250/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0428 - accuracy: 0.9946
# Epoch 251/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0421 - accuracy: 0.9946
# Epoch 252/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0410 - accuracy: 0.9946
# Epoch 253/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0410 - accuracy: 0.9946
# Epoch 254/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0404 - accuracy: 0.9946
# Epoch 255/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0399 - accuracy: 0.9946
# Epoch 256/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0393 - accuracy: 0.9946
# Epoch 257/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0386 - accuracy: 0.9946
# Epoch 258/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0382 - accuracy: 0.9946
# Epoch 259/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0380 - accuracy: 0.9946
# Epoch 260/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0389 - accuracy: 0.9918
# Epoch 261/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0369 - accuracy: 0.9946
# Epoch 262/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0364 - accuracy: 0.9946
# Epoch 263/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0357 - accuracy: 0.9918
# Epoch 264/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0357 - accuracy: 0.9946
# Epoch 265/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0348 - accuracy: 0.9946
# Epoch 266/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0337 - accuracy: 0.9946
# Epoch 267/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0341 - accuracy: 0.9946
# Epoch 268/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0337 - accuracy: 0.9946
# Epoch 269/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 0.9946
# Epoch 270/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0323 - accuracy: 0.9946
# Epoch 271/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0322 - accuracy: 0.9918
# Epoch 272/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0315 - accuracy: 0.9946
# Epoch 273/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 0.9918
# Epoch 274/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0309 - accuracy: 0.9946
# Epoch 275/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0304 - accuracy: 0.9946
# Epoch 276/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0306 - accuracy: 0.9918
# Epoch 277/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0295 - accuracy: 0.9946
# Epoch 278/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0288 - accuracy: 0.9946
# Epoch 279/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0287 - accuracy: 0.9973
# Epoch 280/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0282 - accuracy: 0.9973
# Epoch 281/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0281 - accuracy: 0.9973
# Epoch 282/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0282 - accuracy: 0.9918
# Epoch 283/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0272 - accuracy: 0.9946
# Epoch 284/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0276 - accuracy: 0.9946
# Epoch 285/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0267 - accuracy: 0.9973
# Epoch 286/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0263 - accuracy: 0.9973
# Epoch 287/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0262 - accuracy: 0.9973
# Epoch 288/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0251 - accuracy: 1.0000
# Epoch 289/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 0.9973
# Epoch 290/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0291 - accuracy: 0.9973
# Epoch 291/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0260 - accuracy: 0.9946
# Epoch 292/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0254 - accuracy: 0.9973
# Epoch 293/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0245 - accuracy: 0.9973
# Epoch 294/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 0.9973
# Epoch 295/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0238 - accuracy: 0.9946
# Epoch 296/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 0.9946
# Epoch 297/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 0.9973
# Epoch 298/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0258 - accuracy: 0.9946
# Epoch 299/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0227 - accuracy: 0.9973
# Epoch 300/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0225 - accuracy: 0.9973
# Epoch 301/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0229 - accuracy: 0.9973
# Epoch 302/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0219 - accuracy: 0.9973
# Epoch 303/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0224 - accuracy: 0.9973
# Epoch 304/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0215 - accuracy: 0.9946
# Epoch 305/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0212 - accuracy: 0.9973
# Epoch 306/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 0.9973
# Epoch 307/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0208 - accuracy: 0.9946
# Epoch 308/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0211 - accuracy: 0.9946
# Epoch 309/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0204 - accuracy: 0.9973
# Epoch 310/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 0.9946
# Epoch 311/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0198 - accuracy: 0.9973
# Epoch 312/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0213 - accuracy: 0.9946
# Epoch 313/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0194 - accuracy: 0.9973
# Epoch 314/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 0.9973
# Epoch 315/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0192 - accuracy: 0.9946
# Epoch 316/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0186 - accuracy: 0.9973
# Epoch 317/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0183 - accuracy: 0.9973
# Epoch 318/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9973
# Epoch 319/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 0.9973
# Epoch 320/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0178 - accuracy: 0.9973
# Epoch 321/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0185 - accuracy: 0.9946
# Epoch 322/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 0.9973
# Epoch 323/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 0.9973
# Epoch 324/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0172 - accuracy: 0.9946
# Epoch 325/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0174 - accuracy: 0.9946
# Epoch 326/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0170 - accuracy: 0.9973
# Epoch 327/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0177 - accuracy: 0.9946
# Epoch 328/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 0.9973
# Epoch 329/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9973
# Epoch 330/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0168 - accuracy: 0.9973
# Epoch 331/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0164 - accuracy: 0.9973
# Epoch 332/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 0.9973
# Epoch 333/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0167 - accuracy: 0.9973
# Epoch 334/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0156 - accuracy: 0.9973
# Epoch 335/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 0.9946
# Epoch 336/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0165 - accuracy: 0.9973
# Epoch 337/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0153 - accuracy: 0.9973
# Epoch 338/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0151 - accuracy: 0.9946
# Epoch 339/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0150 - accuracy: 0.9946
# Epoch 340/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 0.9946
# Epoch 341/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0144 - accuracy: 0.9946
# Epoch 342/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 0.9946
# Epoch 343/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0145 - accuracy: 0.9946
# Epoch 344/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0143 - accuracy: 0.9946
# Epoch 345/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0140 - accuracy: 0.9973
# Epoch 346/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0143 - accuracy: 0.9946
# Epoch 347/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 0.9946
# Epoch 348/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0142 - accuracy: 0.9973
# Epoch 349/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 0.9946
# Epoch 350/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 0.9973
# Epoch 351/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 0.9946
# Epoch 352/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 0.9973
# Epoch 353/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0128 - accuracy: 0.9973
# Epoch 354/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 0.9946
# Epoch 355/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 0.9946
# Epoch 356/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 0.9946
# Epoch 357/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0130 - accuracy: 0.9946
# Epoch 358/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 0.9973
# Epoch 359/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0127 - accuracy: 0.9973
# Epoch 360/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 0.9946
# Epoch 361/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 0.9973
# Epoch 362/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0129 - accuracy: 0.9973
# Epoch 363/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0130 - accuracy: 0.9973
# Epoch 364/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0123 - accuracy: 0.9973
# Epoch 365/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0131 - accuracy: 0.9973
# Epoch 366/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0133 - accuracy: 0.9946
# Epoch 367/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0122 - accuracy: 0.9946
# Epoch 368/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0120 - accuracy: 0.9973
# Epoch 369/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 0.9973
# Epoch 370/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0119 - accuracy: 0.9973
# Epoch 371/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0118 - accuracy: 0.9973
# Epoch 372/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0141 - accuracy: 0.9973
# Epoch 373/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0114 - accuracy: 0.9973
# Epoch 374/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0117 - accuracy: 0.9946
# Epoch 375/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.9973
# Epoch 376/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 0.9973
# Epoch 377/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 0.9973
# Epoch 378/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 0.9946
# Epoch 379/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 0.9946
# Epoch 380/500
# 12/12 [==============================] - 0s 4ms/step - loss: 0.0104 - accuracy: 0.9973
# Epoch 381/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 0.9946
# Epoch 382/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 0.9946
# Epoch 383/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 0.9973
# Epoch 384/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 0.9946
# Epoch 385/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 0.9973
# Epoch 386/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0113 - accuracy: 0.9973
# Epoch 387/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0137 - accuracy: 0.9946
# Epoch 388/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0102 - accuracy: 0.9946
# Epoch 389/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0105 - accuracy: 0.9946
# Epoch 390/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 0.9973
# Epoch 391/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 0.9973
# Epoch 392/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 0.9973
# Epoch 393/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 0.9973
# Epoch 394/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0106 - accuracy: 0.9973
# Epoch 395/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 1.0000
# Epoch 396/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0103 - accuracy: 0.9973
# Epoch 397/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0107 - accuracy: 0.9946
# Epoch 398/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0120 - accuracy: 0.9946
# Epoch 399/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 0.9946
# Epoch 400/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0099 - accuracy: 0.9973
# Epoch 401/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0105 - accuracy: 0.9973
# Epoch 402/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 0.9973
# Epoch 403/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 0.9973
# Epoch 404/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 0.9946
# Epoch 405/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 0.9973
# Epoch 406/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0091 - accuracy: 0.9973
# Epoch 407/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 0.9946
# Epoch 408/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 0.9973
# Epoch 409/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 0.9973
# Epoch 410/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0090 - accuracy: 0.9973
# Epoch 411/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0092 - accuracy: 0.9973
# Epoch 412/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 0.9973
# Epoch 413/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 0.9946
# Epoch 414/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 0.9973
# Epoch 415/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 0.9973
# Epoch 416/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 0.9946
# Epoch 417/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 0.9973
# Epoch 418/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 0.9973
# Epoch 419/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 0.9973
# Epoch 420/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 0.9973
# Epoch 421/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0096 - accuracy: 0.9946
# Epoch 422/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 0.9973
# Epoch 423/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 0.9973
# Epoch 424/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 0.9973
# Epoch 425/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 0.9946
# Epoch 426/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0084 - accuracy: 0.9946
# Epoch 427/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 0.9973
# Epoch 428/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 0.9973
# Epoch 429/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 0.9973
# Epoch 430/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 0.9973
# Epoch 431/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0085 - accuracy: 0.9946
# Epoch 432/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0100 - accuracy: 0.9946
# Epoch 433/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0083 - accuracy: 0.9973
# Epoch 434/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 0.9973
# Epoch 435/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 1.0000
# Epoch 436/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0094 - accuracy: 0.9973
# Epoch 437/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 0.9946
# Epoch 438/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 0.9973
# Epoch 439/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9973
# Epoch 440/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9973
# Epoch 441/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0088 - accuracy: 0.9946
# Epoch 442/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 0.9973
# Epoch 443/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 0.9946
# Epoch 444/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 0.9946
# Epoch 445/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9946
# Epoch 446/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 0.9973
# Epoch 447/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 0.9946
# Epoch 448/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 0.9973
# Epoch 449/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 0.9973
# Epoch 450/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0073 - accuracy: 0.9973
# Epoch 451/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0079 - accuracy: 0.9946
# Epoch 452/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9946
# Epoch 453/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.9973
# Epoch 454/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 0.9946
# Epoch 455/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 0.9973
# Epoch 456/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 0.9946
# Epoch 457/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9973
# Epoch 458/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 0.9973
# Epoch 459/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9973
# Epoch 460/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 0.9946
# Epoch 461/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.9973
# Epoch 462/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.9973
# Epoch 463/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.9973
# Epoch 464/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.9946
# Epoch 465/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0074 - accuracy: 0.9973
# Epoch 466/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 0.9973
# Epoch 467/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.9973
# Epoch 468/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9946
# Epoch 469/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0087 - accuracy: 0.9973
# Epoch 470/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.9973
# Epoch 471/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0089 - accuracy: 0.9973
# Epoch 472/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.9973
# Epoch 473/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0076 - accuracy: 0.9973
# Epoch 474/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 0.9973
# Epoch 475/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0066 - accuracy: 0.9973
# Epoch 476/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 0.9973
# Epoch 477/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 0.9973
# Epoch 478/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 0.9973
# Epoch 479/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0070 - accuracy: 0.9946
# Epoch 480/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0069 - accuracy: 0.9973
# Epoch 481/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0080 - accuracy: 0.9946
# Epoch 482/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0065 - accuracy: 0.9973
# Epoch 483/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0056 - accuracy: 1.0000
# Epoch 484/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0082 - accuracy: 0.9973
# Epoch 485/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 0.9973
# Epoch 486/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0071 - accuracy: 0.9973
# Epoch 487/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 0.9946
# Epoch 488/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0077 - accuracy: 0.9946
# Epoch 489/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0090 - accuracy: 0.9946
# Epoch 490/500
# 12/12 [==============================] - 0s 3ms/step - loss: 0.0074 - accuracy: 0.9973
# Epoch 491/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0072 - accuracy: 0.9946
# Epoch 492/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0055 - accuracy: 1.0000
# Epoch 493/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.9973
# Epoch 494/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0064 - accuracy: 0.9973
# Epoch 495/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0062 - accuracy: 0.9973
# Epoch 496/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 0.9946
# Epoch 497/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0065 - accuracy: 0.9946
# Epoch 498/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 0.9946
# Epoch 499/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0061 - accuracy: 0.9973
# Epoch 500/500
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0068 - accuracy: 0.9973

# %%
history_dict = history.history

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")


loss_values = history_dict['loss']
#val_loss_values=history_dict['val_loss']
plt.plot(loss_values,'b',label='training loss')
#plt.plot(val_loss_values,'r',label='val training loss')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
accuracy_values = history_dict['accuracy']
#val_accuracy_values=history_dict['val_accuracy']
#plt.plot(val_accuracy_values,'-r',label='val_accuracy')
plt.plot(accuracy_values,'-b',label='accuracy')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
y_pred = model.predict(padded_sequences)
y_result=[]
for i in y_pred:
    max_value = max(i)
    #print(max_value)
    y_result.append(np.where(i == max_value)[0][0])





from sklearn.metrics import confusion_matrix
#CM matrix for training data
plt.figure(figsize=(12,12))

matrix_nn = confusion_matrix(y_result, np.array(train_intents))

sns.heatmap(matrix_nn, annot=True, cbar=None, cmap="Blues", fmt = 'g')
plt.title("Confusion Matrix"), plt.tight_layout()
plt.ylabel("True Class"), plt.xlabel("Predicted Class")
plt.show()

# %% [markdown]
# ## Save the models
#
# We are saving 3 different things separately
# - Classification model
# - fitted Tokenizer object
# - fitted label encoder object

# %%
# saving model
model.save("chat_model")

import pickle

# saving tokenizer
with open('tokenizer.pickle', 'wb') as handle:
    pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)
    

# saving label encoder
with open('label_encoder.pickle', 'wb') as ecn_file:
    pickle.dump(label_encoder, ecn_file, protocol=pickle.HIGHEST_PROTOCOL)
# Out:
# INFO:tensorflow:Assets written to: chat_model\assets

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\admin\anaconda3\lib\site-packages (4.0.1)

# %%
import json
import random
import datetime
import pymongo
import uuid

# %%
seat_count = 50
import urllib.parse
# Make sure Settings->Network Access has correct settings



password=urllib.parse.quote_plus(<password>)
database = urllib.parse.quote_plus(<Database name>)

URI= mongodb+srv://<hostmame> + password + <clustername> + database + "?" + "retryWrites=true&w=majority"
#client = pymongo.MongoClient(URI)
client = pymongo.MongoClient(URI, connect=False)

db = client[<database name>]
menu_collection = db["menu"]
feedback_collection = db["feedback"]
bookings_collection = db["bookings"]

# %%
query = {"mainmenu": "Y"}

veg_data = menu_collection.find(query)
x=[]
for i in veg_data:
    if (i.get("breakfast")=="N") == True:
        x.append(i.get("item"))
x
# Out:
# ['Soups',
#  'Starters',
#  'Main Course',
#  'Snacks',
#  'Snacks',
#  'Breakfast',
#  'accompaniments']

# %%
# Book a table:
seat_count = 50
def book_table():
    global seat_count
    seat_count = seat_count - 1
    booking_id = str(uuid.uuid4())
    now = datetime.datetime.now()
    booking_time = now.strftime("%Y-%m-%d %H:%M:%S")
    booking_doc = {"booking_id": booking_id, "booking_time": booking_time}
    bookings_collection.insert_one(booking_doc)
    return booking_id


def get_specific_response(tag):
    for intent in data['intents']:
        if intent['tag'] == tag:
            responses = intent['responses']
    response = random.choice(responses)
    return response


def show_menu():
    all_items = menu_collection.distinct('item')
    response = ', '.join(all_items)
    return response

def record_feedback(message, type):
    print("Recording your feedback")
    feedback_doc = {"feedback_string": message, "type": type}
    feedback_collection.insert_one(feedback_doc)
    
def recipe_enquiry(inp):
    response=""
    for i in menu_collection.distinct('item'):
        if i.lower() in inp.lower():
            #print(i)
            #if inp.lower()== i.lower():
        
            query_about= {"item":i}
            about = menu_collection.find(query_about)
            for j in about:
                response = j.get("details")
        
            
    if response =="":
        response = "I don't know much about this recipe! But, you can contact our restaurant for more details."
    return response


def suggest():
    day = datetime.datetime.now()
    day = day.strftime("%A")
    if day == "Monday":
        response = "I would recommend: Paneer Roll and Chicken Biryani"
    elif day == "Tuesday":
        response = "I would recommend: Cheese Grilled Sandwich and Chicken tripple rice"

    elif day == "Wednesday":
        response = "I would recommend: Egg Rolla and Latte "

    elif day == "Thursday":
        response = "I would recommend: Mixed Fruit Juice and Chicken cheese sandwich"

    elif day == "Friday":
        response = "I would recommend: White Sauce Pasta and Cheese cake"

    elif day == "Saturday":
        response = "I would recommend: Chicken Roll and cold coffee"

    elif day == "Sunday":
        response = "I would recommend: Schezwan Rice and Manchurian"
    return response


def veg_menu():
    res=[]    
    query = {"veg": "Y"}
    veg_doc = menu_collection.find(query)
    for x in veg_doc:
        res.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return res

"""def nonveg_menu():
    query = {"nonveg": "Y"}
    vegan_doc = menu_collection.find(query)
    if vegan_doc.count() > 0:
        response = "Non-Vegetarian options are: "
        for x in vegan_doc:
            response = response + str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "; "
        response = response[:-2] # to remove the last ;
    else:
        response = "Sorry no vegetarian options are available"
    return response
"""

def nonveg_menu():
    re=[]
    query = {"nonveg": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        re.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return re




def breakfast_menu():
    br=[]
    query = {"breakfast": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        br.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return br

def bevrages_menu():
    bev=[]
    query = {"icecreams_bev": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        bev.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return bev

def desert_menu():
    de=[]
    query = {"Desert": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        de.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return de

def snacks_menu():
    sn=[]
    query = {"snacks": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        sn.append(str(x.get("item")) + " for Rs. " + str(x.get("cost")) + "\n")
        #response = response[:-2] # to remove the last ;
        #print(response,"\n")
    return sn


def main_menu():
    menu=[]
    query = {"mainmenu": "Y"}
    doc = menu_collection.find(query)
    for x in doc:
        menu.append(str(x.get("item")) +"\n")
   
    return menu

def offers():
    
    response = "Sorry there are no offers available now."
    return response

# %%
def generate_response(tag, user_input):
    global seat_count
    #tag = get_intent(message)
    response = ""
    if tag != "":
        if tag == "book_table":

            if seat_count > 0:
                booking_id = book_table()
                response = "Your table has been booked successfully" + str(
                    booking_id)
            else:
                response = "Sorry we are sold out now!"


        elif tag == "available_tables":
            response = "Right now, there are " + str(seat_count) + " table(s) available."

        elif tag == "veg_enquiry":
            response =veg_menu()

        elif tag == "nonveg_enquiry":
            response =nonveg_menu()
            
        elif tag == "vegan_enquiry":
            response = vegan_menu()

        elif tag == "offers":
            response =offers()

        elif tag == "suggest":
            response =suggest()

        elif tag == "recipe_enquiry":
            response =recipe_enquiry(user_input)

        elif tag == "menu":
            response=main_menu()  #show_menu()
            
        elif tag == "Icecreams_bevrages":
            response = bevrages_menu()
            
        elif tag == "Quick_Bites":
            response1 = snacks_menu()
            response2= breakfast_menu()
            response3 = bevrages_menu()
            response = response1 + response2 + response3
            
        elif tag == "positive_feedback":
            record_feedback(user_input, "positive")
            response = "Thank you so much for your valuable feedback. We look forward to serving you again!"

        elif "negative_feedback" == tag:
            record_feedback(user_input, "negative")
            response = "Thank you so much for your valuable feedback. We deeply regret the inconvenience. We have " \
                       "forwarded your concerns to the authority and hope to satisfy you better the next time! "
        # for other intents with pre-defined responses that can be pulled from dataset
        else:
            response = get_specific_response(tag)
    else:
        response = "Sorry! I didn't get it, please try to be more precise."
    return response

# %% [markdown]
# ### Load the model

# %%
"""import json 
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder

import colorama 
colorama.init()
from colorama import Fore, Style, Back

import random
import pickle

with open("intents.json") as file:
    data = json.load(file)


def chat():
    # load trained model
    model = keras.models.load_model('chat_model')

    # load tokenizer object
    with open('tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # load label encoder object
    with open('label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # parameters
    max_len = 20
    
    while True:
        print(Fore.LIGHTBLUE_EX + "User: " + Style.RESET_ALL, end="")
        inp = input()
        if inp.lower() == "quit":
            break

        result = model.predict(keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([inp]),truncating='post', maxlen=max_len))
        #print("result: ", result)
        #print(result.max())
        #print(np.where(result == (result.max())))

        ## Find the intent
        tag = lbl_encoder.inverse_transform([np.argmax(result)])
        print(tag)

        for i in data['intents']:
            if i['tag'] == tag:
                output = generate_response(tag, inp)
                #print(len(output))
                print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , output)
                #print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , np.random.choice(i['responses']))

        

print(Fore.YELLOW + "Start messaging with the bot (type quit to stop)!" + Style.RESET_ALL)
chat()"""
# Out:
# 'import json \nimport numpy as np\nfrom tensorflow import keras\nfrom sklearn.preprocessing import LabelEncoder\n\nimport colorama \ncolorama.init()\nfrom colorama import Fore, Style, Back\n\nimport random\nimport pickle\n\nwith open("intents.json") as file:\n    data = json.load(file)\n\n\ndef chat():\n    # load trained model\n    model = keras.models.load_model(\'chat_model\')\n\n    # load tokenizer object\n    with open(\'tokenizer.pickle\', \'rb\') as handle:\n        tokenizer = pickle.load(handle)\n\n    # load label encoder object\n    with open(\'label_encoder.pickle\', \'rb\') as enc:\n        lbl_encoder = pickle.load(enc)\n\n    # parameters\n    max_len = 20\n    \n    while True:\n        print(Fore.LIGHTBLUE_EX + "User: " + Style.RESET_ALL, end="")\n        inp = input()\n        if inp.lower() == "quit":\n            break\n\n        result = model.predict(keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([inp]),truncating=\'post\', maxlen=max_len))\n        #print("result: ", result)\n        #print(result.max())\n        #print(np.where(result == (result.max())))\n\n        ## Find the intent\n        tag = lbl_encoder.inverse_transform([np.argmax(result)])\n        print(tag)\n\n        for i in data[\'intents\']:\n            if i[\'tag\'] == tag:\n                output = generate_response(tag, inp)\n                #print(len(output))\n                print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , output)\n                #print(Fore.GREEN + "ChatBot:" + Style.RESET_ALL , np.random.choice(i[\'responses\']))\n\n        \n\nprint(Fore.YELLOW + "Start messaging with the bot (type quit to stop)!" + Style.RESET_ALL)\nchat()'

# %%
def response_gen(message):
    model = keras.models.load_model('chat_model')

    # load tokenizer object
    with open('tokenizer.pickle', 'rb') as handle:
        tokenizer = pickle.load(handle)

    # load label encoder object
    with open('label_encoder.pickle', 'rb') as enc:
        lbl_encoder = pickle.load(enc)

    # parameters
    max_len = 20
    
    result = model.predict(keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([message]),truncating='post', maxlen=max_len))
    
    ## Find the intent
    tag = lbl_encoder.inverse_transform([np.argmax(result)])
    print(tag)

    for i in data['intents']:
        if i['tag'] == tag:
            output = generate_response(tag, message)
            
    return output

# %%
from flask import Flask, render_template, request, jsonify
import json 
import numpy as np
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder



app = Flask(__name__)


@app.route('/')
def index():
    return render_template('index.html')


@app.route('/get')
def get_bot_response():
    
    message = request.args.get('msg')
    response = ""
    if message:
        response = response_gen(message)
        
        return str(response)
    else:
        return "Missing Data!"


if __name__ == "__main__":
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [10/Feb/2022 14:42:50] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [10/Feb/2022 14:42:55] "GET /get?msg=Hi HTTP/1.1" 200 -
# ['greeting']
# 127.0.0.1 - - [10/Feb/2022 14:42:56] "GET /get?msg=veg HTTP/1.1" 200 -
# ['veg_enquiry']
# 127.0.0.1 - - [10/Feb/2022 14:43:01] "GET /get?msg=okay HTTP/1.1" 200 -
# ['general']
# 127.0.0.1 - - [10/Feb/2022 14:43:12] "GET /get?msg=nonveg HTTP/1.1" 200 -
# ['nonveg_enquiry']
# 127.0.0.1 - - [10/Feb/2022 14:43:16] "GET /get?msg=all HTTP/1.1" 200 -
# ['greeting']
# 127.0.0.1 - - [10/Feb/2022 14:43:22] "GET /get?msg=bye HTTP/1.1" 200 -
# ['goodbye']

# %% [markdown]
# ### TODO
# Offers<br>
# Cancel Table<br>
# item based search<br>
# order status
